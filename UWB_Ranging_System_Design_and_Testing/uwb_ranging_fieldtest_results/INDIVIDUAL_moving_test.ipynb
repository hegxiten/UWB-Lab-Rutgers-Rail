# %% [markdown]
# ## Moving Test 1 (V2V) Results

# %%
import os, re
import json
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter

from datetime import datetime
import math
import pandas as pd
from itertools import chain

from utils import post_process_get_moving_test_data_and_timestamp
from utils import remove_outlier_by_quantile
from static_data_processing import get_test_files_and_survey
from plot_utils import *
from stats_utils import *

from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

from collections import defaultdict

ROOT_DIR = os.path.join("C:/Users/wangz/OneDrive/University_RU/NSUWB/")
CALIBRATED_CAM_TO_V2B = -6400.8
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', None)

RESAMPLE_RULE = "1S"
PLOTTING_DPI = 75
static_main_master = '0C1A'
static_focusing_slaves = ['1912', '8D38']
static_master_slave_mapping = { '0C1A': [static_focusing_slaves[0], static_focusing_slaves[1]],
                        '9B0F': [static_focusing_slaves[1], static_focusing_slaves[0]]}
moving_main_master = '88BA'
moving_focusing_slaves = ['45BA', '0B8A']
moving_master_slave_mapping = { '88BA': [moving_focusing_slaves[0], moving_focusing_slaves[1]],
                        '111C': [moving_focusing_slaves[1], moving_focusing_slaves[0]]}
STATIC_VEH, MOVING_VEH = 1, 2
VEH_NAME_MAP = {1: "static", 2: "moving"}
test_preset_map = defaultdict(dict)
test_preset_map['PLOTTING_DPI'] = PLOTTING_DPI
test_preset_map['STATIC_VEH'] = STATIC_VEH
test_preset_map['MOVING_VEH'] = MOVING_VEH
test_preset_map[STATIC_VEH]['master_slave_mapping'] = static_master_slave_mapping
test_preset_map[MOVING_VEH]['master_slave_mapping'] = moving_master_slave_mapping
test_preset_map[STATIC_VEH]['main_master'] = static_main_master
test_preset_map[MOVING_VEH]['main_master'] = moving_main_master
#############################################
# if skip plotting any tests, list them here
skiptests = []
#############################################
all_test_files, ground_truth_list = post_process_get_moving_test_data_and_timestamp(ROOT_DIR, 
                                                                                    "Moving Test 1 (V2V)", 
                                                                                    "V2", 
                                                                                    CALIBRATED_CAM_TO_V2B,
                                                                                    skiptests=skiptests)
assert(len(all_test_files) == len(ground_truth_list))
all_test_names_dup = [os.path.basename(os.path.dirname(f)) for f in all_test_files]
# Remove Duplicates of Test Names
all_test_names = []
_ = [all_test_names.append(x) for x in all_test_names_dup if x not in all_test_names]
test_raw_name_file_map = {}
for i in range(len(all_test_names)):
    test_raw_name_file_map[all_test_names[i]] = {}
    a_side_file, b_side_file = all_test_files[2*i], all_test_files[2*i+1]
    test_raw_name_file_map[all_test_names[i]]["A"] = a_side_file
    test_raw_name_file_map[all_test_names[i]]["B"] = b_side_file
    test_raw_name_file_map[all_test_names[i]]["ground_truth"] = ground_truth_list[2*i]
moving_tests = {}

# %% [markdown]
# ## 2021-05-25-10-46-56-moving-v2-1-west-walking-speed

# %%
test_1_west = all_test_names[0]
moving_tests[test_1_west] = parse_single_test_data(test_raw_name_file_map[test_1_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_1_west]["ground_truth"])
plot_single_test_data(test_1_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-10-46-56-moving-v2-1-west-walking-speed
# plotting: 2021-05-25-10-46-56-moving-v2-1-west-walking-speed

# %% [markdown]
# ## 2021-05-25-10-55-51-moving-v2-1-east-reset

# %%
test_1_east = all_test_names[1]
moving_tests[test_1_east] = parse_single_test_data(test_raw_name_file_map[test_1_east]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_1_east]["ground_truth"])
plot_single_test_data(test_1_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-10-55-51-moving-v2-1-east-reset
# 2021-05-25-10-55-51-moving-v2-1-east-reset No Data
# 2021-05-25-10-55-51-moving-v2-1-east-reset No Data, Not Plotting

# %% [markdown]
# ## 2021-05-25-11-00-35-moving-v2-2-west-3mph

# %%
test_2_west = all_test_names[2]
moving_tests[test_2_west] = parse_single_test_data(test_raw_name_file_map[test_2_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_2_west]["ground_truth"])
plot_single_test_data(test_2_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-00-35-moving-v2-2-west-3mph
# plotting: 2021-05-25-11-00-35-moving-v2-2-west-3mph

# %% [markdown]
# ## 2021-05-25-11-02-33-moving-v2-2-east-reset

# %%
test_2_east = all_test_names[3]
moving_tests[test_2_east] = parse_single_test_data(test_raw_name_file_map[test_2_east]["B"], "Moving Test",
                                                   test_raw_name_file_map[test_2_east]["ground_truth"])
plot_single_test_data(test_2_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-02-33-moving-v2-2-east-reset
# 2021-05-25-11-02-33-moving-v2-2-east-reset No Data
# 2021-05-25-11-02-33-moving-v2-2-east-reset No Data, Not Plotting

# %% [markdown]
# ## 2021-05-25-11-06-29-moving-v2-3-west-5mph

# %%
test_3_west = all_test_names[4]
moving_tests[test_3_west] = parse_single_test_data(test_raw_name_file_map[test_3_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_3_west]["ground_truth"])
plot_single_test_data(test_3_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-06-29-moving-v2-3-west-5mph
# plotting: 2021-05-25-11-06-29-moving-v2-3-west-5mph

# %% [markdown]
# ## 2021-05-25-11-09-46-moving-v2-3-east-reset

# %%
test_3_east = all_test_names[5]
moving_tests[test_3_east] = parse_single_test_data(test_raw_name_file_map[test_3_east]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_3_east]["ground_truth"])
plot_single_test_data(test_3_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-09-46-moving-v2-3-east-reset
# plotting: 2021-05-25-11-09-46-moving-v2-3-east-reset

# %% [markdown]
# ## 2021-05-25-11-09-46-moving-v2-3-east-reset

# %%
test_4_west = all_test_names[6]
moving_tests[test_4_west] = parse_single_test_data(test_raw_name_file_map[test_4_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_4_west]["ground_truth"])
plot_single_test_data(test_4_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-13-08-moving-v2-4-west-12mph
# plotting: 2021-05-25-11-13-08-moving-v2-4-west-12mph

# %% [markdown]
# ## 2021-05-25-11-15-00-moving-v2-4-east-reset

# %%
test_4_east = all_test_names[7]
moving_tests[test_4_east] = parse_single_test_data(test_raw_name_file_map[test_4_east]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_4_east]["ground_truth"])
plot_single_test_data(test_4_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-15-00-moving-v2-4-east-reset
# plotting: 2021-05-25-11-15-00-moving-v2-4-east-reset

# %% [markdown]
# ## 2021-05-25-11-19-48-moving-v2-5-west-12mph

# %%
test_5_west = all_test_names[8]
moving_tests[test_5_west] = parse_single_test_data(test_raw_name_file_map[test_5_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_5_west]["ground_truth"])
plot_single_test_data(test_5_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-19-48-moving-v2-5-west-12mph
# plotting: 2021-05-25-11-19-48-moving-v2-5-west-12mph

# %% [markdown]
# ## 2021-05-25-11-19-48-moving-v2-5-west-12mph

# %%
test_5_east = all_test_names[9]
moving_tests[test_5_east] = parse_single_test_data(test_raw_name_file_map[test_5_east]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_5_east]["ground_truth"])
plot_single_test_data(test_5_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-21-44-moving-v2-5-east-reset
# 2021-05-25-11-21-44-moving-v2-5-east-reset No Data
# 2021-05-25-11-21-44-moving-v2-5-east-reset No Data, Not Plotting

# %% [markdown]
# ## 2021-05-25-11-19-48-moving-v2-5-west-12mph

# %%
test_6_west = all_test_names[10]
moving_tests[test_6_west] = parse_single_test_data(test_raw_name_file_map[test_6_west]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_6_west]["ground_truth"])
plot_single_test_data(test_6_west, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-24-00-moving-v2-6-west-fullspeed
# plotting: 2021-05-25-11-24-00-moving-v2-6-west-fullspeed

# %% [markdown]
# ## 2021-05-25-11-26-40-moving-v2-6-east-reset

# %%
test_6_east = all_test_names[11]
moving_tests[test_6_east] = parse_single_test_data(test_raw_name_file_map[test_6_east]["B"], "Moving Test", test_preset_map, 
                                                   test_raw_name_file_map[test_6_east]["ground_truth"])
plot_single_test_data(test_6_east, moving_tests, 'Moving Test', test_preset_map)
# Out:
# processing: 2021-05-25-11-26-40-moving-v2-6-east-reset
# plotting: 2021-05-25-11-26-40-moving-v2-6-east-reset
